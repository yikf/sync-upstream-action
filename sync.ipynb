# %%
import run_sync

if __name__ == "__main__":
    run_sync.main()
# Out:
# usage: ipykernel_launcher.py [-h] [--config CONFIG] [--token TOKEN]
#                              [--owner OWNER]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/bytedance/Library/Jupyter/runtime/kernel-v3e4d7c146379efcb325bc3694f95368ccc6a6fbc6.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
